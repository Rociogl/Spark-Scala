// %% [markdown]
// # Proyecto  Final -  Parte 4

// %% [markdown]
// ### **Parte 4. Spark  Structured Streaming**

// %% [markdown]
// - 1. [Pasos previos](#1)
// - 2. [Análisis agua](#2)

// %% [markdown]
// En esta última parte, se van a analizar los datos aportados por el puerto 45002, emite datos refentes a los consumos de agua

// %% [markdown]
// <a id="1"></a>
// ### * 1. Pasos previos al análisis e importación de librerias*

// %%
import org.apache.spark._

// %%
import org.apache.spark.streaming._

// %%
import org.apache.spark.sql.streaming._

// %%
import org.apache.spark.sql.SparkSession

// %%
import org.apache.spark.sql.functions._

// %%
import org.apache.spark.sql.Row

// %%
import org.apache.spark.sql.types._

// %%
import java.sql.Timestamp

// %%
val spark = SparkSession.builder.getOrCreate()
// Out:
// spark = org.apache.spark.sql.SparkSession@3d2a2aa6
// Spark local-1580498039657: Some(http://master:4040)

// %% [markdown]
// #### * Se registra la fuente de datos*

// %%
val datos_raw = spark.readStream.format("socket").option("host","emisor.eoi.rbs-net.com").option("port", 45002).load()
// Out:
// datos_raw = [value: string]
// [value: string]

// %%
val datos_campos = datos_raw.withColumn("tmp", split($"value", ";"))
// Out:
// datos_campos = [value: string, tmp: array<string>]
// [value: string, tmp: array<string>]

// %% [markdown]
// #### * Se le asigna nombre a las columnas y se con que tipo de dato las reconoce*

// %%
val datos_cabec = datos_campos.select($"tmp".getItem(0).as("Edificio").cast("string"),
                                      $"tmp".getItem(1).as("Consumo").cast("double"),
                                      $"tmp".getItem(2).as("Año").cast("integer"),
                                      $"tmp".getItem(3).as("Mes").cast("integer"),
                                      $"tmp".getItem(4).as("Día").cast("integer"),
                                      $"tmp".getItem(5).as("Hora").cast("integer"),
                                      $"tmp".getItem(6).as("Minuto").cast("integer"))
// Out:
// datos_cabec = [Edificio: string, Consumo: double ... 5 more fields]
// [Edificio: string, Consumo: double ... 5 more fields]

// %% [markdown]
// #### * Se agrupan los datos en una columna llamada fecha*

// %%
val datos_cabe_ok = datos_cabec.select($"Edificio",$"Consumo",(concat($"Año", lit("-"), 
                                          $"Mes", lit("-"), 
                                          $"Día", lit(" "), 
                                          $"Hora", lit(":"),
                                          $"Minuto").cast("Timestamp").as("Fecha")))
// Out:
// datos_cabe_ok = [Edificio: string, Consumo: double ... 1 more field]
// [Edificio: string, Consumo: double ... 1 more field]

// %%
datos_cabe_ok.printSchema
// Out:
// root
//  |-- Edificio: string (nullable = true)
//  |-- Consumo: double (nullable = true)
//  |-- Fecha: timestamp (nullable = true)

// %% [markdown]
// <a id="2"></a>
// ### * 2. Análisis de los datos del agua *

// %% [markdown]
// #### *Se muestran por pantalla sin que se elimine ninguna parte, la tabla datos con los elementos recibidos en cada uno de los intervalos  *

// %%
val query_1 = datos_cabe_ok.writeStream.
format("console").
option("truncate", false).
option("numRows", 30).
start()
// Out:
// query_1 = org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@47c43ee7
// org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@47c43ee7
// -------------------------------------------
// Batch: 0
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_20|0.27   |2013-10-15 14:45:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 1
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_20|0.3    |2013-10-15 15:00:00|
// |AGUA_EDIF_20|0.28   |2013-10-15 15:15:00|
// |AGUA_EDIF_20|0.33   |2013-10-15 15:30:00|
// |AGUA_EDIF_20|0.22   |2013-10-15 15:45:00|
// |AGUA_EDIF_20|0.21   |2013-10-15 16:00:00|
// |AGUA_EDIF_20|0.22   |2013-10-15 16:15:00|
// |AGUA_EDIF_20|0.25   |2013-10-15 16:30:00|
// |AGUA_EDIF_20|0.26   |2013-10-15 16:45:00|
// |AGUA_EDIF_20|0.35   |2013-10-15 17:00:00|
// |AGUA_EDIF_20|0.25   |2013-10-15 17:15:00|
// |AGUA_EDIF_20|0.25   |2013-10-15 17:30:00|
// |AGUA_EDIF_20|0.25   |2013-10-15 17:45:00|
// |AGUA_EDIF_20|0.24   |2013-10-15 18:00:00|
// |AGUA_EDIF_20|0.24   |2013-10-15 18:15:00|
// |AGUA_EDIF_20|0.24   |2013-10-15 18:30:00|
// |AGUA_EDIF_20|0.23   |2013-10-15 18:45:00|
// |AGUA_EDIF_20|0.23   |2013-10-15 19:00:00|
// |AGUA_EDIF_20|0.17   |2013-10-15 19:15:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 2
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_20|0.16   |2013-10-15 19:30:00|
// |AGUA_EDIF_20|0.14   |2013-10-15 19:45:00|
// |AGUA_EDIF_20|0.17   |2013-10-15 20:00:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 3
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_20|0.04   |2013-10-15 20:15:00|
// |AGUA_EDIF_20|0.0    |2013-10-15 20:30:00|
// |AGUA_EDIF_20|0.0    |2013-10-15 20:45:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 4
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_20|0.0    |2013-10-15 21:00:00|
// |AGUA_EDIF_20|0.0    |2013-10-15 21:15:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 5
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_20|0.0    |2013-10-15 21:30:00|
// |AGUA_EDIF_20|0.0    |2013-10-15 21:45:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 6
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_20|0.0    |2013-10-15 22:00:00|
// |AGUA_EDIF_20|0.0    |2013-10-15 22:15:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 7
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_20|0.0    |2013-10-15 22:30:00|
// |AGUA_EDIF_20|0.0    |2013-10-15 22:45:00|
// |AGUA_EDIF_20|0.0    |2013-10-15 23:00:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 8
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_20|0.0    |2013-10-15 23:15:00|
// |AGUA_EDIF_20|0.02   |2013-10-15 23:30:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 9
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_20|0.02   |2013-10-15 23:45:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 10
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_21|0.0    |2013-10-15 00:00:00|
// |AGUA_EDIF_21|0.0    |2013-10-15 00:15:00|
// |AGUA_EDIF_21|0.0    |2013-10-15 00:30:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 11
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_21|0.0    |2013-10-15 00:45:00|
// |AGUA_EDIF_21|0.0    |2013-10-15 01:00:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 12
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_21|0.0    |2013-10-15 01:15:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 13
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_21|0.0    |2013-10-15 01:30:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 14
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_21|0.0    |2013-10-15 01:45:00|
// |AGUA_EDIF_21|0.0    |2013-10-15 02:00:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 15
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_21|0.0    |2013-10-15 02:15:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 16
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_21|0.0    |2013-10-15 02:30:00|
// |AGUA_EDIF_21|0.0    |2013-10-15 02:45:00|
// |AGUA_EDIF_21|0.0    |2013-10-15 03:00:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 17
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_21|0.0    |2013-10-15 03:15:00|
// |AGUA_EDIF_21|0.0    |2013-10-15 03:30:00|
// +------------+-------+-------------------+
//
// -------------------------------------------
// Batch: 18
// -------------------------------------------
// +------------+-------+-------------------+
// |Edificio    |Consumo|Fecha              |
// +------------+-------+-------------------+
// |AGUA_EDIF_21|0.0    |2013-10-15 03:45:00|
// +------------+-------+-------------------+

// %% [markdown]
// #### * Se analizan los consumos por edificio *

// %%
val query_2_aux = datos_cabe_ok.groupBy($"Edificio").agg(sum($"Consumo") as "Consumo (m3)")
// Out:
// query_2_aux = [Edificio: string, Consumo (m3): double]
// [Edificio: string, Consumo (m3): double]

// %%
val query_2 = query_2_aux.writeStream.format("console").
outputMode("complete").queryName("query_2").option("truncate", false).
start()
// Out:
// query_2 = org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@4838888a
// org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@4838888a
// -------------------------------------------
// Batch: 0
// -------------------------------------------
// +------------+------------+
// |Edificio    |Consumo (m3)|
// +------------+------------+
// |﻿AGUA_EDIF_1|0.0         |
// +------------+------------+
//
// -------------------------------------------
// Batch: 1
// -------------------------------------------
// +------------+------------------+
// |Edificio    |Consumo (m3)      |
// +------------+------------------+
// |AGUA_EDIF_1 |3.9800000000000004|
// |﻿AGUA_EDIF_1|0.0               |
// +------------+------------------+
//
// -------------------------------------------
// Batch: 2
// -------------------------------------------
// +------------+------------+
// |Edificio    |Consumo (m3)|
// +------------+------------+
// |AGUA_EDIF_1 |4.62        |
// |﻿AGUA_EDIF_1|0.0         |
// +------------+------------+
//
// -------------------------------------------
// Batch: 3
// -------------------------------------------
// +--------------------+------------+
// |Edificio            |Consumo (m3)|
// +--------------------+------------+
// |AGUA_EDIF_1_CAFETERI|0.0         |
// |AGUA_EDIF_1         |4.62        |
// |﻿AGUA_EDIF_1        |0.0         |
// +--------------------+------------+
//
// -------------------------------------------
// Batch: 4
// -------------------------------------------
// +--------------------+-------------------+
// |Edificio            |Consumo (m3)       |
// +--------------------+-------------------+
// |AGUA_EDIF_1_CAFETERI|0.30000000000000004|
// |AGUA_EDIF_1         |4.62               |
// |﻿AGUA_EDIF_1        |0.0                |
// +--------------------+-------------------+
//
// -------------------------------------------
// Batch: 5
// -------------------------------------------
// +--------------------+------------+
// |Edificio            |Consumo (m3)|
// +--------------------+------------+
// |AGUA_EDIF_1_CAFETERI|2.01        |
// |AGUA_EDIF_1         |4.62        |
// |﻿AGUA_EDIF_1        |0.0         |
// +--------------------+------------+
//
// -------------------------------------------
// Batch: 6
// -------------------------------------------
// +--------------------+-----------------+
// |Edificio            |Consumo (m3)     |
// +--------------------+-----------------+
// |AGUA_EDIF_1_CAFETERI|4.279999999999999|
// |AGUA_EDIF_1         |4.62             |
// |﻿AGUA_EDIF_1        |0.0              |
// +--------------------+-----------------+
//
// -------------------------------------------
// Batch: 7
// -------------------------------------------
// +--------------------+-----------------+
// |Edificio            |Consumo (m3)     |
// +--------------------+-----------------+
// |AGUA_EDIF_1_CAFETERI|4.619999999999999|
// |AGUA_EDIF_1         |4.62             |
// |﻿AGUA_EDIF_1        |0.0              |
// +--------------------+-----------------+
//
// -------------------------------------------
// Batch: 8
// -------------------------------------------
// +--------------------+-----------------+
// |Edificio            |Consumo (m3)     |
// +--------------------+-----------------+
// |AGUA_EDIF_1_CAFETERI|4.619999999999999|
// |AGUA_EDIF_10        |0.01             |
// |AGUA_EDIF_1         |4.62             |
// |﻿AGUA_EDIF_1        |0.0              |
// +--------------------+-----------------+

// %% [markdown]
// #### * Se calcula el número de registros por Edificio junto con la media de los consumos*

// %%
val query_3_aux = datos_cabe_ok.groupBy($"Edificio").agg(count($"Consumo") as "Número de registros", round(avg($"Consumo"),2) as "Media de los registros")
// Out:
// query_3_aux = [Edificio: string, Número de registros: bigint ... 1 more field]
// [Edificio: string, Número de registros: bigint ... 1 more field]

// %%
val query_3 = query_3_aux.writeStream.format("console").
outputMode("complete").queryName("query_2").option("truncate", false).
start()
// Out:
// query_3 = org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@334c5c1a
// org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@334c5c1a
// -------------------------------------------
// Batch: 0
// -------------------------------------------
// +-----------+-------------------+----------------------+
// |Edificio   |Número de registros|Media de los registros|
// +-----------+-------------------+----------------------+
// |AGUA_EDIF_3|1                  |0.1                   |
// +-----------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 1
// -------------------------------------------
// +-----------+-------------------+----------------------+
// |Edificio   |Número de registros|Media de los registros|
// +-----------+-------------------+----------------------+
// |AGUA_EDIF_3|36                 |0.06                  |
// +-----------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 2
// -------------------------------------------
// +-----------+-------------------+----------------------+
// |Edificio   |Número de registros|Media de los registros|
// +-----------+-------------------+----------------------+
// |AGUA_EDIF_3|58                 |0.04                  |
// +-----------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 3
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|15                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 4
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|31                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 5
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|47                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 6
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|61                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 7
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|78                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 8
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|94                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 9
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_32|13                 |0.01                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 10
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_32|28                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 11
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_32|44                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 12
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_32|60                 |0.03                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 13
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_32|75                 |0.03                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 14
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_32|92                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 15
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|12                 |0.01                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 16
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|27                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 17
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|44                 |0.03                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
// -------------------------------------------
// Batch: 18
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|61                 |0.03                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 19
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|81                 |0.03                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 20
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |7                  |0.0                   |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 21
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |25                 |0.01                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 22
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |38                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 23
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |53                 |0.03                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 24
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |71                 |0.03                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 25
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |83                 |0.03                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 26
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|4                  |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 27
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|19                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 28
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|31                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 29
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|47                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 30
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|62                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
// -------------------------------------------
// Batch: 31
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|75                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 32
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|92                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 33
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_43|14                 |0.0                   |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 34
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_43|27                 |0.01                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 35
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_43|45                 |0.03                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 36
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_43|59                 |0.03                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 37
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_43|75                 |0.03                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 38
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_43|93                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 39
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|12                 |0.0                   |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 40
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|27                 |0.0                   |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 41
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|44                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 42
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|56                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 43
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|71                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 44
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|84                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 45
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|5                  |0.0                   |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 46
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|21                 |0.0                   |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 47
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|38                 |0.0                   |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 48
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|53                 |0.0                   |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 49
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|74                 |0.0                   |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 50
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|91                 |0.0                   |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 51
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |7                  |0.0                   |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
// -------------------------------------------
// Batch: 52
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |25                 |0.0                   |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 53
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |41                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 54
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |58                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 55
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |70                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 56
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |83                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 57
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |96                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 58
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_6 |14                 |0.0                   |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |96                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 59
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_6 |32                 |0.01                  |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |96                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 60
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_6 |50                 |0.02                  |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |96                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
// -------------------------------------------
// Batch: 61
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_6 |69                 |0.02                  |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |96                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 62
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_6 |84                 |0.02                  |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |96                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 63
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_6 |96                 |0.01                  |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |96                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_7 |7                  |0.02                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 64
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_6 |96                 |0.01                  |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |96                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_7 |27                 |0.04                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 65
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_6 |96                 |0.01                  |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |96                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_7 |44                 |0.09                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 66
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_6 |96                 |0.01                  |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |96                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_7 |61                 |0.11                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 67
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_6 |96                 |0.01                  |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |96                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_7 |91                 |0.11                  |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 68
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_8 |22                 |0.0                   |
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_6 |96                 |0.01                  |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |96                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_7 |96                 |0.1                   |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 69
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_8 |49                 |0.03                  |
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_6 |96                 |0.01                  |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |96                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_7 |96                 |0.1                   |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 70
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_EDIF_8 |80                 |0.03                  |
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_6 |96                 |0.01                  |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |96                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_7 |96                 |0.1                   |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 71
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_UPO    |15                 |0.54                  |
// |AGUA_EDIF_8 |96                 |0.02                  |
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_6 |96                 |0.01                  |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |96                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_7 |96                 |0.1                   |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+
//
// -------------------------------------------
// Batch: 72
// -------------------------------------------
// +------------+-------------------+----------------------+
// |Edificio    |Número de registros|Media de los registros|
// +------------+-------------------+----------------------+
// |AGUA_UPO    |52                 |1.77                  |
// |AGUA_EDIF_8 |96                 |0.02                  |
// |AGUA_EDIF_31|96                 |0.0                   |
// |AGUA_EDIF_6 |96                 |0.01                  |
// |AGUA_EDIF_42|96                 |0.0                   |
// |AGUA_EDIF_3 |60                 |0.04                  |
// |AGUA_EDIF_45|96                 |0.0                   |
// |AGUA_EDIF_5 |96                 |0.02                  |
// |AGUA_EDIF_36|96                 |0.03                  |
// |AGUA_EDIF_4 |96                 |0.02                  |
// |AGUA_EDIF_7 |96                 |0.1                   |
// |AGUA_EDIF_44|96                 |0.01                  |
// |AGUA_EDIF_43|96                 |0.02                  |
// |AGUA_EDIF_32|96                 |0.02                  |
// +------------+-------------------+----------------------+

// %% [markdown]
// #### * Calculo del número de consumos que se realizan en los ultimos 15 minutos*

// %%
val query_3_aux = datos_cabe_ok.groupBy($"Edificio", window($"Fecha", "15 minutes", "9 minutes")).count()
// Out:
// query_3_aux = [Edificio: string, window: struct<start: timestamp, end: timestamp> ... 1 more field]
// [Edificio: string, window: struct<start: timestamp, end: timestamp> ... 1 more field]

// %%
val query_3 = query_3_aux.writeStream.format("console").
outputMode("update").queryName("query_3").option("truncate", false).
start()
// Out:
// query_3 = org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@3f3ab03d
// org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@3f3ab03d
// -------------------------------------------
// Batch: 0
// -------------------------------------------
// +--------------------+------------------------------------------+-----+
// |Edificio            |window                                    |count|
// +--------------------+------------------------------------------+-----+
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 12:39:00, 2013-10-15 12:54:00]|1    |
// +--------------------+------------------------------------------+-----+
//
// -------------------------------------------
// Batch: 1
// -------------------------------------------
// +--------------------+------------------------------------------+-----+
// |Edificio            |window                                    |count|
// +--------------------+------------------------------------------+-----+
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 14:27:00, 2013-10-15 14:42:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 15:12:00, 2013-10-15 15:27:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 17:09:00, 2013-10-15 17:24:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 16:51:00, 2013-10-15 17:06:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 14:36:00, 2013-10-15 14:51:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 15:48:00, 2013-10-15 16:03:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 17:27:00, 2013-10-15 17:42:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 17:54:00, 2013-10-15 18:09:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 14:18:00, 2013-10-15 14:33:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 14:54:00, 2013-10-15 15:09:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 16:15:00, 2013-10-15 16:30:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 13:15:00, 2013-10-15 13:30:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 17:36:00, 2013-10-15 17:51:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 15:21:00, 2013-10-15 15:36:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 13:51:00, 2013-10-15 14:06:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 16:42:00, 2013-10-15 16:57:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 13:33:00, 2013-10-15 13:48:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 17:45:00, 2013-10-15 18:00:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 15:03:00, 2013-10-15 15:18:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 17:00:00, 2013-10-15 17:15:00]|1    |
// +--------------------+------------------------------------------+-----+
// only showing top 20 rows
//
// -------------------------------------------
// Batch: 2
// -------------------------------------------
// +--------------------+------------------------------------------+-----+
// |Edificio            |window                                    |count|
// +--------------------+------------------------------------------+-----+
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 18:21:00, 2013-10-15 18:36:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 19:06:00, 2013-10-15 19:21:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 19:24:00, 2013-10-15 19:39:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 18:30:00, 2013-10-15 18:45:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 21:12:00, 2013-10-15 21:27:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 20:00:00, 2013-10-15 20:15:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 21:57:00, 2013-10-15 22:12:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 18:39:00, 2013-10-15 18:54:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 20:45:00, 2013-10-15 21:00:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 21:30:00, 2013-10-15 21:45:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 20:18:00, 2013-10-15 20:33:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 19:33:00, 2013-10-15 19:48:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 20:09:00, 2013-10-15 20:24:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 18:12:00, 2013-10-15 18:27:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 18:48:00, 2013-10-15 19:03:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 19:51:00, 2013-10-15 20:06:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 19:15:00, 2013-10-15 19:30:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 19:42:00, 2013-10-15 19:57:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 20:27:00, 2013-10-15 20:42:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 21:21:00, 2013-10-15 21:36:00]|1    |
// +--------------------+------------------------------------------+-----+
// only showing top 20 rows
//
// -------------------------------------------
// Batch: 3
// -------------------------------------------
// +--------------------+------------------------------------------+-----+
// |Edificio            |window                                    |count|
// +--------------------+------------------------------------------+-----+
// |AGUA_EDIF_10        |[2013-10-15 01:06:00, 2013-10-15 01:21:00]|1    |
// |AGUA_EDIF_10        |[2013-10-15 00:03:00, 2013-10-15 00:18:00]|1    |
// |AGUA_EDIF_10        |[2013-10-15 01:33:00, 2013-10-15 01:48:00]|1    |
// |AGUA_EDIF_10        |[2013-10-15 00:57:00, 2013-10-15 01:12:00]|1    |
// |AGUA_EDIF_10        |[2013-10-15 00:30:00, 2013-10-15 00:45:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 22:06:00, 2013-10-15 22:21:00]|1    |
// |AGUA_EDIF_10        |[2013-10-15 01:51:00, 2013-10-15 02:06:00]|1    |
// |AGUA_EDIF_10        |[2013-10-15 02:09:00, 2013-10-15 02:24:00]|1    |
// |AGUA_EDIF_10        |[2013-10-15 00:12:00, 2013-10-15 00:27:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 22:33:00, 2013-10-15 22:48:00]|1    |
// |AGUA_EDIF_10        |[2013-10-15 01:15:00, 2013-10-15 01:30:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 23:09:00, 2013-10-15 23:24:00]|1    |
// |AGUA_EDIF_10        |[2013-10-15 02:00:00, 2013-10-15 02:15:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 23:36:00, 2013-10-15 23:51:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 23:00:00, 2013-10-15 23:15:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 22:51:00, 2013-10-15 23:06:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 23:45:00, 2013-10-16 00:00:00]|1    |
// |AGUA_EDIF_10        |[2013-10-15 01:42:00, 2013-10-15 01:57:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 22:15:00, 2013-10-15 22:30:00]|1    |
// |AGUA_EDIF_1_CAFETERI|[2013-10-15 23:27:00, 2013-10-15 23:42:00]|1    |
// +--------------------+------------------------------------------+-----+
// only showing top 20 rows

// %% [markdown]
// #### * Teniendo e cuenta que el mecanismo de watermarking permite a Spark ignorar aquellos datos que han sido generados en un instante de tiempo en el que NO es relevante para los resultados, por ejemplo se supone que no es relevante conservar los datos generados en los últimos 15 minutos. Además se añade una columan con el consumo máximo *

// %%
val query_4_aux = datos_cabe_ok.withWatermark("Fecha","15 minutes")
    .groupBy($"Edificio", window($"Fecha", "30 minutes", "30 minutes"))
    .agg(max($"Consumo") as "Consumo máximo")
    .sort(asc("window"))
// Out:
// query_4_aux = [Edificio: string, window: struct<start: timestamp, end: timestamp> ... 1 more field]
// [Edificio: string, window: struct<start: timestamp, end: timestamp> ... 1 more field]

// %%
val query_4 = query_4_aux.writeStream.format("console").
outputMode("complete").queryName("query_4").option("truncate", false).
start()
// Out:
// query_4 = org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@36089358
// org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@36089358
// -------------------------------------------
// Batch: 0
// -------------------------------------------
// +------------+------------------------------------------+--------------+
// |Edificio    |window                                    |Consumo máximo|
// +------------+------------------------------------------+--------------+
// |AGUA_EDIF_14|[2013-10-15 01:30:00, 2013-10-15 02:00:00]|0.0           |
// +------------+------------------------------------------+--------------+
//
// -------------------------------------------
// Batch: 1
// -------------------------------------------
// +------------+------------------------------------------+--------------+
// |Edificio    |window                                    |Consumo máximo|
// +------------+------------------------------------------+--------------+
// |AGUA_EDIF_15|[2013-10-15 00:00:00, 2013-10-15 00:30:00]|0.26          |
// |AGUA_EDIF_15|[2013-10-15 00:30:00, 2013-10-15 01:00:00]|0.04          |
// |AGUA_EDIF_15|[2013-10-15 01:00:00, 2013-10-15 01:30:00]|0.0           |
// |AGUA_EDIF_14|[2013-10-15 01:30:00, 2013-10-15 02:00:00]|0.0           |
// |AGUA_EDIF_15|[2013-10-15 01:30:00, 2013-10-15 02:00:00]|0.0           |
// |AGUA_EDIF_15|[2013-10-15 02:00:00, 2013-10-15 02:30:00]|0.0           |
// |AGUA_EDIF_14|[2013-10-15 02:00:00, 2013-10-15 02:30:00]|0.0           |
// |AGUA_EDIF_15|[2013-10-15 02:30:00, 2013-10-15 03:00:00]|0.0           |
// |AGUA_EDIF_14|[2013-10-15 02:30:00, 2013-10-15 03:00:00]|0.0           |
// |AGUA_EDIF_14|[2013-10-15 03:00:00, 2013-10-15 03:30:00]|0.0           |
// |AGUA_EDIF_15|[2013-10-15 03:00:00, 2013-10-15 03:30:00]|0.01          |
// |AGUA_EDIF_15|[2013-10-15 03:30:00, 2013-10-15 04:00:00]|0.0           |
// |AGUA_EDIF_14|[2013-10-15 03:30:00, 2013-10-15 04:00:00]|0.0           |
// |AGUA_EDIF_15|[2013-10-15 04:00:00, 2013-10-15 04:30:00]|0.0           |
// |AGUA_EDIF_14|[2013-10-15 04:00:00, 2013-10-15 04:30:00]|0.0           |
// |AGUA_EDIF_15|[2013-10-15 04:30:00, 2013-10-15 05:00:00]|0.01          |
// |AGUA_EDIF_14|[2013-10-15 04:30:00, 2013-10-15 05:00:00]|0.0           |
// |AGUA_EDIF_14|[2013-10-15 05:00:00, 2013-10-15 05:30:00]|0.0           |
// |AGUA_EDIF_15|[2013-10-15 05:00:00, 2013-10-15 05:30:00]|0.0           |
// |AGUA_EDIF_15|[2013-10-15 05:30:00, 2013-10-15 06:00:00]|0.09          |
// +------------+------------------------------------------+--------------+
// only showing top 20 rows

// %% [markdown]
// #### * Cálculo del Edificio en el que ha habido el mayor consumo en los últimos 2 días*

// %%
val query_5_aux = datos_cabe_ok.groupBy(window($"Fecha", "48 hours", "48 hours"), $"Edificio")
    .agg(sum($"Consumo") as "Mayor Consumo")
    .sort(asc("window"))
    .sort(desc("Mayor Consumo"))
// Out:
// query_5_aux = [window: struct<start: timestamp, end: timestamp>, Edificio: string ... 1 more field]
// [window: struct<start: timestamp, end: timestamp>, Edificio: string ... 1 more field]

// %%
val query_5 = query_5_aux.writeStream.format("console").
outputMode("complete").queryName("query_4").option("truncate", false).
start()
// Out:
// query_5 = org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@495f96ba
// org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@495f96ba
// -------------------------------------------
// Batch: 0
// -------------------------------------------
// +------------------------------------------+------------+-------------+
// |window                                    |Edificio    |Mayor Consumo|
// +------------------------------------------+------------+-------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|0.04         |
// +------------------------------------------+------------+-------------+
//
// -------------------------------------------
// Batch: 1
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.0               |
// +------------------------------------------+------------+------------------+
//
// -------------------------------------------
// Batch: 2
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// +------------------------------------------+------------+------------------+
//
// -------------------------------------------
// Batch: 3
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.755             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// +------------------------------------------+------------+------------------+
//
// -------------------------------------------
// Batch: 4
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.968             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_44|0.0               |
// +------------------------------------------+------------+------------------+
//
// -------------------------------------------
// Batch: 5
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.968             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_44|0.79              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// +------------------------------------------+------------+------------------+
//
// -------------------------------------------
// Batch: 6
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.968             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_44|0.8500000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_45|0.0               |
// +------------------------------------------+------------+------------------+
//
// -------------------------------------------
// Batch: 7
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.968             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_44|0.8500000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_45|0.0               |
// +------------------------------------------+------------+------------------+
//
// -------------------------------------------
// Batch: 8
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.968             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_44|0.8500000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_45|0.0               |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_5 |0.0               |
// +------------------------------------------+------------+------------------+
//
// -------------------------------------------
// Batch: 9
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.968             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_5 |0.89              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_44|0.8500000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_45|0.0               |
// +------------------------------------------+------------+------------------+
//
// -------------------------------------------
// Batch: 10
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.968             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_5 |1.49              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_44|0.8500000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_45|0.0               |
// +------------------------------------------+------------+------------------+
// -------------------------------------------
// Batch: 11
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.968             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_5 |1.49              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_44|0.8500000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_6 |0.34              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_45|0.0               |
// +------------------------------------------+------------+------------------+
//
// -------------------------------------------
// Batch: 12
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.968             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_5 |1.49              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_6 |1.3900000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_44|0.8500000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_45|0.0               |
// +------------------------------------------+------------+------------------+
//
// -------------------------------------------
// Batch: 13
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.968             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_5 |1.49              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_6 |1.3900000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_44|0.8500000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_7 |0.61              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_45|0.0               |
// +------------------------------------------+------------+------------------+
//
// -------------------------------------------
// Batch: 14
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_7 |6.66              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.968             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_5 |1.49              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_6 |1.3900000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_44|0.8500000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_45|0.0               |
// +------------------------------------------+------------+------------------+
//
// -------------------------------------------
// Batch: 15
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_7 |9.59              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.968             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_5 |1.49              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_6 |1.3900000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_44|0.8500000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_45|0.0               |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_8 |0.0               |
// +------------------------------------------+------------+------------------+
//
// -------------------------------------------
// Batch: 16
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_7 |9.59              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.968             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_8 |1.8000000000000003|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_5 |1.49              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_6 |1.3900000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_44|0.8500000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_45|0.0               |
// +------------------------------------------+------------+------------------+
//
// -------------------------------------------
// Batch: 17
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_7 |9.59              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_UPO    |9.17              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_8 |2.1000000000000005|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.968             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_5 |1.49              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_6 |1.3900000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_44|0.8500000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_45|0.0               |
// +------------------------------------------+------------+------------------+
//
// -------------------------------------------
// Batch: 18
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_UPO    |83.66000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_7 |9.59              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_8 |2.1000000000000005|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.968             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_5 |1.49              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_6 |1.3900000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_44|0.8500000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_45|0.0               |
// +------------------------------------------+------------+------------------+
// -------------------------------------------
// Batch: 19
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_UPO    |159.11            |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_7 |9.59              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_8 |2.1000000000000005|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.968             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_5 |1.49              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_6 |1.3900000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_44|0.8500000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_45|0.0               |
// +------------------------------------------+------------+------------------+
//
// -------------------------------------------
// Batch: 20
// -------------------------------------------
// +------------------------------------------+------------+------------------+
// |window                                    |Edificio    |Mayor Consumo     |
// +------------------------------------------+------------+------------------+
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_UPO    |162.63000000000002|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_7 |9.59              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_4 |2.3000000000000007|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_8 |2.1000000000000005|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_43|1.968             |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_36|1.900000000000001 |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_5 |1.49              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_6 |1.3900000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_44|0.8500000000000001|
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_42|0.02              |
// |[2013-10-14 02:00:00, 2013-10-16 02:00:00]|AGUA_EDIF_45|0.0               |
// +------------------------------------------+------------+------------------+

// %%
query_5.stop

// %% [markdown]
// ### * Se listan las queries que se encuentran en ejecución en este momento. *

// %%
spark.streams.active

// %% [markdown]
// ### * Se finalizan las queries*

// %%
query_1.stop
query_2.stop
query_3.stop
query_4.stop
query_5.stop
query_6.stop
// Out:
// Name: Unknown Error
// Message: <console>:64: error: not found: value query_6
//        query_6.stop
//        ^
// <console>:57: error: not found: value query_1
//        query_1.stop
//        ^
// <console>:58: error: not found: value query_2
//        query_2.stop
//        ^
// <console>:59: error: not found: value query_3
//        query_3.stop
//        ^
// <console>:60: error: not found: value query_4
//        query_4.stop
//        ^
//
// StackTrace:
